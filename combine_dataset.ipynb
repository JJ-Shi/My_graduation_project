# %%
import pandas as pd
import math
from tqdm import tqdm

# %%
data_2017 = pd.read_csv('every_year_combined_dataset\combined_data_2017.csv', sep=',')

# %%
data_2017
# Out:
#                NPI  Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  \
# 0       1174525315                     37.0             53              941
# 1       1174525364                     12.0             39             1780
# 2       1174525414                     31.0            143              487
# 3       1174525497                      9.0             25              516
# 4       1174525729                     26.0             86             2000
# ...            ...                      ...            ...              ...
# 280568  1992999122                     12.0             43             1349
# 280569  1992999270                     12.0              5               12
# 280570  1992999551                      6.0             49              382
# 280571  1992999759                     13.0             28              238
# 280572  1992999874                     51.0             11              134
#
# ...

# %%
data_2018 = pd.read_csv('every_year_combined_dataset\combined_data_2018.csv', sep=',')
data_2018
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (116) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                NPI  Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  \
# 0       1164875647                     39.0             19              162
# 1       1164875654                     24.0             34              179
# 2       1164875720                      8.0             40              222
# 3       1164875894                     12.0             57              476
# 4       1164877296                     12.0             53              306
# ...            ...                      ...            ...              ...
# 283244  1992998736                     12.0             31              160
# 283245  1992999122                     12.0             42             1293
# ...

# %%
#Remove the feature NPI
data_2018.drop(labels = 'NPI', axis = 1, inplace = True)
data_2017.drop(labels = 'NPI', axis = 1, inplace = True)

# %%
#The 17 and 18 datasets were combined
data_1718_combined = pd.concat([data_2017,data_2018], ignore_index = True, sort = False)

# %%
data_1718_combined
# Out:
#         Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  Tot_Srvcs  \
# 0                          37.0             53              941     6053.0
# 1                          12.0             39             1780     5902.0
# 2                          31.0            143              487    13646.0
# 3                           9.0             25              516     2201.0
# 4                          26.0             86             2000     5962.0
# ...                         ...            ...              ...        ...
# 563817                     12.0             31              160      604.0
# 563818                     12.0             42             1293     7652.0
# 563819                     12.0             24               62      141.0
# 563820                      6.0             50              334     1111.0
# 563821                     13.0             30               77      301.0
#
# ...

# %%
#Zeroes are added to the merged dataset
data_1718_combined.fillna(0, inplace = True)

# %%
data_1718_combined
# Out:
#         Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  Tot_Srvcs  \
# 0                          37.0             53              941     6053.0
# 1                          12.0             39             1780     5902.0
# 2                          31.0            143              487    13646.0
# 3                           9.0             25              516     2201.0
# 4                          26.0             86             2000     5962.0
# ...                         ...            ...              ...        ...
# 563817                     12.0             31              160      604.0
# 563818                     12.0             42             1293     7652.0
# 563819                     12.0             24               62      141.0
# 563820                      6.0             50              334     1111.0
# 563821                     13.0             30               77      301.0
#
# ...

# %%
#The two datasets are stored as training and testing sets, respectively
data_1718_combined.to_csv('train_and_test_dataset\combined_data_1718.csv', index = False)
data_2019.to_csv('train_and_test_dataset\combined_data_19.csv', index = False)

# %%
data_2019 = pd.read_csv('every_year_combined_dataset\combined_data_2019.csv', sep=',')
data_2019
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (116) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                NPI  Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  \
# 0       1164795670                     23.0             12               81
# 1       1164796801                     12.0             10              478
# 2       1164797098                     27.0              4              115
# 3       1164797205                      6.0             23               93
# 4       1164797833                     39.0             15              124
# ...            ...                      ...            ...              ...
# 285250  1992998736                     12.0             43              130
# 285251  1992999122                     12.0             35             1320
# ...

# %%
data_2019
# Out:
#         Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_PartB  Tot_Srvcs  \
# 0                          23.0             12               81       97.0
# 1                          12.0             10              478     2200.0
# 2                          27.0              4              115      425.0
# 3                           6.0             23               93      232.0
# 4                          39.0             15              124      571.0
# ...                         ...            ...              ...        ...
# 285250                     12.0             43              130      601.0
# 285251                     12.0             35             1320     7403.0
# 285252                     12.0             28              108      197.0
# 285253                      6.0             44              408     1239.0
# 285254                     13.0             29               35      315.0
#
# ...
