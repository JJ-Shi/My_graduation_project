# %%
import pandas as pd
import math
from tqdm import tqdm

#log the LEIE dataset
crime_col_names =['LASTNAME','FIRSTNAME','MIDNAME','BUSNAME','GENERAL','SPECIALTY','UPIN','NPI','DOB','ADDRESS','CITY','STATE','ZIP','EXCLTYPE','EXCLDATE','REINDATE','WAIVERDATE','WVRSTATE']
crime_data = pd.read_csv('LEIE\LEIE.csv', header = None, names = crime_col_names)
crime_data = pd.DataFrame(crime_data).loc[1:].reset_index(drop=True)

crime_data
# Out:
#      LASTNAME FIRSTNAME   MIDNAME                      BUSNAME  \
# 0         NaN       NaN              #1 MARKETING SERVICE, INC
# 1         NaN       NaN            101 FIRST CARE PHARMACY INC
# 2         NaN       NaN               14 LAWRENCE AVE PHARMACY
# 3         NaN       NaN               143 MEDICAL EQUIPMENT CO
# 4         NaN       NaN             184TH STREET PHARMACY CORP
# ...       ...       ...       ...                          ...
# 9945    BOREL   MONIQUE    RENEE                           NaN
# 9946   BORELA   LINCOLN   ARTHUR                           NaN
# 9947  BORELLI   ANTHONY                                    NaN
# 9948    BOREN  KATHLEEN        S                           NaN
# 9949    BOREN   MICHAEL  CHARLES                           NaN
#
#                    GENERAL          SPECIALTY UPIN         NPI       DOB  \
# 0           OTHER BUSINESS         SOBER HOME  NaN  0000000000       NaN
# ...

# %%
#Extract data on crimes committed in 2017 and later
crime_data_2017 = []
nan = str('nan')
zero = '0000000000'

for row in tqdm(crime_data.itertuples()):
    if str(getattr(row, 'EXCLDATE')) != nan:
        if int(str(getattr(row, 'EXCLDATE'))[0:4]) >= 2017:
            if getattr(row, 'NPI') != zero:
                crime_data_2017.append(row)
                
crime_data_2017 = pd.DataFrame(crime_data_2017)
# Out:
# 9950it [00:00, 399064.09it/s]

# %%
crime_data_2017
# Out:
#      Index           LASTNAME FIRSTNAME     MIDNAME  \
# 0        1                NaN       NaN
# 1        4                NaN       NaN
# 2       24                NaN       NaN
# 3       31                NaN       NaN
# 4       60                NaN       NaN
# ..     ...                ...       ...         ...
# 461   9709    BOLDRIDGE-GROSS      JANE        ANN
# 462   9720             BOLGER      PAUL    MATTHEW
# 463   9743            BOLLING    GEORGE  RICHARD JR
# 464   9938             BORDEN     WENDY       LYNN
# 465   9942  BORDERS-BLACKWELL     ANNIE
#
#                             BUSNAME               GENERAL  \
# 0       101 FIRST CARE PHARMACY INC        OTHER BUSINESS
# 1        184TH STREET PHARMACY CORP        OTHER BUSINESS
# 2         A & Y MEDICAL SUPPLY, INC           DME COMPANY
# 3         A FAIR DEAL PHARMACY, INC        OTHER BUSINESS
# 4    ACACIA MENTAL HEALTH CLINIC, L        OTHER BUSINESS
# ...

# %%
#Save the generated crime 2017 data
crime_data_2017.to_csv('crime_data/crime_Data_2017.csv',index = False)

# %%
#Extract data on crimes committed in 2018 and later
crime_data_2018 = []
nan = str('nan')
zero = '0000000000'

for row in tqdm(crime_data.itertuples()):
    if str(getattr(row, 'EXCLDATE')) != nan:
        if int(str(getattr(row, 'EXCLDATE'))[0:4]) >= 2018:
            if getattr(row, 'NPI') != zero:
                crime_data_2018.append(row)
                
crime_data_2018 = pd.DataFrame(crime_data_2018)
# Out:
# 9950it [00:00, 369514.39it/s]

# %%
crime_data_2018
# Out:
#      Index   LASTNAME FIRSTNAME     MIDNAME                         BUSNAME  \
# 0        1        NaN       NaN                 101 FIRST CARE PHARMACY INC
# 1        4        NaN       NaN                  184TH STREET PHARMACY CORP
# 2       60        NaN       NaN              ACACIA MENTAL HEALTH CLINIC, L
# 3       62        NaN       NaN                   ACCESS 2 INTEGRATION, INC
# 4      115        NaN       NaN                    AFFORDABLE PHARMACY, INC
# ..     ...        ...       ...         ...                             ...
# 371   9675    BOHLMAN     PETER   ANDREW JR                             NaN
# 372   9684  BOINPALLY     ASHOK                                         NaN
# 373   9720     BOLGER      PAUL    MATTHEW                              NaN
# 374   9743    BOLLING    GEORGE  RICHARD JR                             NaN
# 375   9938     BORDEN     WENDY       LYNN                              NaN
#
# ...

# %%
#Save the generated crime 2018 data
crime_data_2018.to_csv('crime_data/crime_Data_2018.csv',index = False)

# %%
#Extract data on crimes committed in 2019 and later
crime_data_2019 = []
nan = str('nan')
zero = '0000000000'

for row in tqdm(crime_data.itertuples()):
    if str(getattr(row, 'EXCLDATE')) != nan:
        if int(str(getattr(row, 'EXCLDATE'))[0:4]) >= 2019:
            if getattr(row, 'NPI') != zero:
                crime_data_2019.append(row)
                
crime_data_2019 = pd.DataFrame(crime_data_2019)
# Out:
# 9950it [00:00, 113434.13it/s]

# %%
crime_data_2019
# Out:
#      Index   LASTNAME FIRSTNAME    MIDNAME                         BUSNAME  \
# 0        1        NaN       NaN                101 FIRST CARE PHARMACY INC
# 1       60        NaN       NaN             ACACIA MENTAL HEALTH CLINIC, L
# 2       62        NaN       NaN                  ACCESS 2 INTEGRATION, INC
# 3      115        NaN       NaN                   AFFORDABLE PHARMACY, INC
# 4      121        NaN       NaN             AIM PHARMACY AND SURGICALS COR
# ..     ...        ...       ...        ...                             ...
# 285   9673    BOHLMAN    ANDREW     LANCE                              NaN
# 286   9675    BOHLMAN     PETER  ANDREW JR                             NaN
# 287   9684  BOINPALLY     ASHOK                                        NaN
# 288   9720     BOLGER      PAUL   MATTHEW                              NaN
# 289   9938     BORDEN     WENDY      LYNN                              NaN
#
# ...

# %%
#Save the generated crime 2019 data
crime_data_2019.to_csv('crime_data/crime_Data_2019.csv',index = False)
